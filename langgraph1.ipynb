# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka2709/Assignment/blob/main/langgraph1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langgraph langchain langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.2/246.2 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.4
#     Uninstalling langgraph-1.2.4:
#       Successfully uninstalled langgraph-1.2.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.6
#     Uninstalling langchain-1.3.6:
#       Successfully uninstalled langchain-1.3.6
# ...

# %%
from typing import TypedDict

class State(TypedDict):
    message: str

# %%
def greet(state):
    return {"message": f"Hello {state['message']}"}

# %%
from langgraph.graph import StateGraph, START, END

builder = StateGraph(State)

builder.add_node("greet", greet)
builder.add_edge(START, "greet")
builder.add_edge("greet", END)

graph = builder.compile()

# %%
result = graph.invoke({"message": "Anushka"})
print(result)
# Out:
# {'message': 'Hello Anushka'}
